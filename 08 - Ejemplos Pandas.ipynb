# %% [markdown]
# <a href="https://colab.research.google.com/github/alfonsocude/MACHINE-LEARNING-1/blob/main/08%20-%20Ejemplos%20Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
# **Recuerda que una vez abierto, Da clic en "Copiar en Drive", de lo contrario no podras alamancenar tu progreso**
#
# Nota: no olvide ir ejecutando las celdas de código de arriba hacia abajo para que no tenga errores de importación de librerías o por falta de definición de variables.

# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/alfonsocude/MACHINE-LEARNING-1/main/init.py
import init; init.init(force_download=False);
# Out:
# replicating local resources

# %% [markdown]
# # Ejemplos Pandas
#
# Ahora unos ejemplos usando Pandas y un [dataset the Pokemon](https://github.com/travishn/pokemon-showdown-scraper/tree/master/pokemon-data).

# %%
import pandas as pd

# %% [markdown]
# Leer un CSV es bastante fácil usando Pandas

# %%
df_gen1 = pd.read_csv("local/data/pokemon-gen1-data.csv")
df_gen2 = pd.read_csv("local/data/pokemon-gen2-data.csv")

# %% [markdown]
# Ahora podemos crear unas breves descripciones de los datos...

# %%
df_gen1.head()
# Out:
#       Pokemon  Number  Type1   Type2  Ability1     Ability2 Ability3  HP  \
# 0   Bulbasaur       1  GRASS  POISON  Overgrow  Chlorophyll     none  45
# 1     Ivysaur       2  GRASS  POISON  Overgrow  Chlorophyll     none  60
# 2    Venusaur       3  GRASS  POISON  Overgrow  Chlorophyll     none  80
# 3  Charmander       4   FIRE    none     Blaze  Solar Power     none  39
# 4  Charmeleon       5   FIRE    none     Blaze  Solar Power     none  58
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0      49       49       65       65     45
# 1      62       63       80       80     60
# 2      82       83      100      100     80
# 3      52       43       60       50     65
# 4      64       58       80       65     80
#
#                                               Sprite
# 0  https://play.pokemonshowdown.com/sprites/bw/bu...
# 1  https://play.pokemonshowdown.com/sprites/bw/iv...
# 2  https://play.pokemonshowdown.com/sprites/bw/ve...
# 3  https://play.pokemonshowdown.com/sprites/bw/ch...
# 4  https://play.pokemonshowdown.com/sprites/bw/ch...

# %%
df_gen2.head()# para ver los primeros 5
# Out:
#      Pokemon  Number  Type1 Type2  Ability1    Ability2 Ability3  HP  Attack  \
# 0  Chikorita     152  GRASS  none  Overgrow  Leaf Guard     none  45      49
# 1    Bayleef     153  GRASS  none  Overgrow  Leaf Guard     none  60      62
# 2   Meganium     154  GRASS  none  Overgrow  Leaf Guard     none  80      82
# 3  Cyndaquil     155   FIRE  none     Blaze  Flash Fire     none  39      52
# 4    Quilava     156   FIRE  none     Blaze  Flash Fire     none  58      64
#
#    Defense  Sp. Atk  Sp. Def  Speed  \
# 0       65       49       65     45
# 1       80       63       80     60
# 2      100       83      100     80
# 3       43       60       50     65
# 4       58       80       65     80
#
#                                               Sprite
# 0  https://play.pokemonshowdown.com/sprites/bw/ch...
# 1  https://play.pokemonshowdown.com/sprites/bw/ba...
# 2  https://play.pokemonshowdown.com/sprites/bw/me...
# 3  https://play.pokemonshowdown.com/sprites/bw/cy...
# 4  https://play.pokemonshowdown.com/sprites/bw/qu...

# %% [markdown]
# podemos combinar ambos datasets en uno solo, para manejarlo más fácilmente

# %%
df = pd.concat([df_gen1, df_gen2], keys=["gen1", "gen2"])

# %%
df
# Out:
#             Pokemon  Number    Type1   Type2      Ability1     Ability2  \
# gen1 0    Bulbasaur       1    GRASS  POISON      Overgrow  Chlorophyll
#      1      Ivysaur       2    GRASS  POISON      Overgrow  Chlorophyll
#      2     Venusaur       3    GRASS  POISON      Overgrow  Chlorophyll
#      3   Charmander       4     FIRE    none         Blaze  Solar Power
#      4   Charmeleon       5     FIRE    none         Blaze  Solar Power
# ...             ...     ...      ...     ...           ...          ...
# gen2 95     Pupitar     247     ROCK  GROUND     Shed Skin         none
#      96   Tyranitar     248     ROCK    DARK   Sand Stream      Unnerve
#      97       Lugia     249  PSYCHIC  FLYING      Pressure   Multiscale
#      98       Ho-Oh     250     FIRE  FLYING      Pressure  Regenerator
#      99      Celebi     251  PSYCHIC   GRASS  Natural Cure         none
#
#         Ability3   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# gen1 0      none   45      49       49       65       65     45
#      1      none   60      62       63       80       80     60
#      2      none   80      82       83      100      100     80
#      3      none   39      52       43       60       50     65
#      4      none   58      64       58       80       65     80
# ...          ...  ...     ...      ...      ...      ...    ...
# gen2 95     none   70      84       70       65       70     51
#      96     none  100     134      110       95      100     61
#      97     none  106      90      130       90      154    110
#      98     none  106     130       90      110      154     90
#      99     none  100     100      100      100      100    100
#
#                                                     Sprite
# gen1 0   https://play.pokemonshowdown.com/sprites/bw/bu...
#      1   https://play.pokemonshowdown.com/sprites/bw/iv...
#      2   https://play.pokemonshowdown.com/sprites/bw/ve...
#      3   https://play.pokemonshowdown.com/sprites/bw/ch...
#      4   https://play.pokemonshowdown.com/sprites/bw/ch...
# ...                                                    ...
# gen2 95  https://play.pokemonshowdown.com/sprites/bw/pu...
#      96  https://play.pokemonshowdown.com/sprites/bw/ty...
#      97  https://play.pokemonshowdown.com/sprites/bw/lu...
#      98  https://play.pokemonshowdown.com/sprites/bw/ho...
#      99  https://play.pokemonshowdown.com/sprites/bw/ce...
#
# [251 rows x 14 columns]

# %%
import numpy as np

np.random.seed(10)# usar semillla

df_gen2.sample(10) #para ver los ultimos 5
# Out:
#       Pokemon  Number   Type1     Type2     Ability1       Ability2  \
# 19    Lanturn     171   WATER  ELECTRIC  Volt Absorb     Illuminate
# 14     Ledian     166     BUG    FLYING        Swarm     Early Bird
# 43   Quagsire     195   WATER    GROUND         Damp   Water Absorb
# 37   Jumpluff     189   GRASS    FLYING  Chlorophyll     Leaf Guard
# 66     Slugma     218    FIRE      none  Magma Armor     Flame Body
# 3   Cyndaquil     155    FIRE      none        Blaze     Flash Fire
# 79     Phanpy     231  GROUND      none       Pickup      Sand Veil
# 41      Yanma     193     BUG    FLYING  Speed Boost  Compound Eyes
# 38      Aipom     190  NORMAL      none     Run Away         Pickup
# 68     Swinub     220     ICE    GROUND    Oblivious     Snow Cloak
#
#         Ability3   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 19  Water Absorb  125      58       58       76       76     67
# 14     Iron Fist   55      35       50       55      110     85
# 43       Unaware   95      85       85       65       65     35
# 37   Infiltrator   75      55       70       55       95    110
# 66    Weak Armor   40      40       40       70       40     20
# 3           none   39      52       43       60       50     65
# 79          none   90      60       60       40       40     40
# 41         Frisk   65      65       45       75       45     95
# 38    Skill Link   55      70       55       40       55     85
# 68     Thick Fat   50      50       40       30       30     50
#
#                                                Sprite
# 19  https://play.pokemonshowdown.com/sprites/bw/la...
# 14  https://play.pokemonshowdown.com/sprites/bw/le...
# 43  https://play.pokemonshowdown.com/sprites/bw/qu...
# 37  https://play.pokemonshowdown.com/sprites/bw/ju...
# 66  https://play.pokemonshowdown.com/sprites/bw/sl...
# 3   https://play.pokemonshowdown.com/sprites/bw/cy...
# 79  https://play.pokemonshowdown.com/sprites/bw/ph...
# 41  https://play.pokemonshowdown.com/sprites/bw/ya...
# 38  https://play.pokemonshowdown.com/sprites/bw/ai...
# 68  https://play.pokemonshowdown.com/sprites/bw/sw...

# %% [markdown]
# Honestamente, a mí me parece un poco más enredado trabajar con múltiples índices, por lo que convertiré los datos a un dataframe con un solo índice

# %%
df = df.reset_index(level=0).rename(columns={"level_0": "generation"}).reset_index().drop(columns="index")
df.head()

# %% [markdown]
# podemos sacar un breve resumen de nuestro dataset

# %%
df.describe()

# %% [markdown]
# A partir de este punto puedes empezar a utilizar pandas para responder las preguntas que acerca de tus datos.
#
# **¿Cuántos Pokemon hay en cada generación?***

# %%
df.groupby("generation").size()

# %% [markdown]
# **¿Cuáles son los tipos de Pokemon con mayor velocidad promedio?**

# %%
df.groupby("Type1").mean()["Speed"]

# %%
df[["generation", "HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]].groupby("generation").mean()
